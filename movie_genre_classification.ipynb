# %%
import pandas as pd
import plotly.express as px
from sklearn.decomposition import PCA
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv('train_data.txt', sep=' ::: ', engine='python', names=['Title', 'Genre', 'Description'], nrows=6000)

df.head()
# Out:
#                               Title     Genre  \
# 1      Oscar et la dame rose (2009)     drama
# 2                      Cupid (1997)  thriller
# 3  Young, Wild and Wonderful (1980)     adult
# 4             The Secret Sin (1915)     drama
# 5            The Unrecovered (2007)     drama
#
#                                          Description
# 1  Listening in to a conversation between his doc...
# 2  A brother and sister with a past incestuous re...
# 3  As the bus empties the students for their fiel...
# 4  To help their unemployed father make ends meet...
# 5  The film's title refers not only to the un-rec...

# %%
df['Genre'].value_counts()
# Out:
# drama          1481
# documentary    1459
# comedy          830
# short           559
# horror          235
# thriller        211
# action          146
# western         116
# reality-tv      100
# family           82
# adventure        82
# sci-fi           79
# music            75
# adult            73
# romance          58
# animation        54
# sport            51
# crime            48
# talk-show        41
# mystery          37
# biography        36
# fantasy          35
# musical          29
# history          27
# game-show        25
# news             18
# war              13
# Name: Genre, dtype: int64

# %%
df = df[
    (df['Genre'] == 'drama') | (df['Genre'] == 'music') | (df['Genre'] == 'documentary') | (df['Genre'] == 'western')]

# %%
vec = TfidfVectorizer(stop_words='english')

# %%
matrix = vec.fit_transform(df['Description'])

# %%
X = matrix.toarray()

# %%
len(vec.get_feature_names_out())
# Out:
# 27288

# %%
vec.get_feature_names_out()
# Out:
# array(['00', '000', '000km', ..., 'żestán', 'żo', 'żte'], dtype=object)

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# %%
fig = px.scatter(x=X_pca[:, 0], y=X_pca[:, 1], color=df['Genre'], hover_name=df['Title'], template='plotly_dark')
fig.update_layout(
    title="2 Component PCA visualization of Movie Genres",
    xaxis_title="1st Principal Component",
    yaxis_title="2nd Principal Component",
)
fig.show()
# Out:
# <div>                            <div id="fa15c1b7-2e6f-4429-abcf-994fce26570c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa15c1b7-2e6f-4429-abcf-994fce26570c")) {                    Plotly.newPlot(                        "fa15c1b7-2e6f-4429-abcf-994fce26570c",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>color=drama<br>x=%{x}<br>y=%{y}<extra></extra>","hovertext":["Oscar et la dame rose (2009)","The Secret Sin (1915)","The Unrecovered (2007)","In the Gloaming (1997)","The Glass Menagerie (1973)","Night Call (2016)","O Signo das Tetas (2016)","Wedded Bliss? (2002)","Heroin (2013/I)","La dama del alba (1966)","A Thousand Acres (1997)","La Habanera (1937)","The Painter (2015/I)","Wojeck: Out of the Fire (1992)","Herr \u00fcber Leben und Tod (1955)","Ranta (2006)","O Amuleto de Ogum (1974)","Smooth Operator (1995/I)","Minus zwei (2005)","Blood on the Wall$ (2005)","Bartleby (1970/II)","Crime Delicado (2005)","Agni kai atimasmeni (1962)","Dr. Del (2016)","Henry & Verlin (1996)","Pokriv (1978)","\"Elles et moi\" (2008)","Heart Breaks Open (2011)","\"Schicksale - und pl\u00f6tzlich ist alles anders\" (2010)","Medius (2016)","D'Encre et de Sang (2016)","Red Cap (2001)","An (2015)","Nayikar Mato (2016)","Forgotten Sins (1996)","Madame X (1937)","La verdad sobre el caso Savolta (1980)","Knafayim Shvurot (2002)","Koibitotachi (2015)","Balarrasa (1951)","A Child Is Born (1939)","Lois Gibbs and the Love Canal (1982)","O Padre e a Mo\u00e7a (1966)","Before It's Too Late: A Film on Teenage Suicide (1985)","12: The Tamir Rice Story (????/I)","\"Head 2 Toe\" (2003)","Bigga Than Ben (2008)","Baboyngirongbuang (2010)","\"Do Not Be Afraid\" (2007)","Ironsides (2009)","The Green Swamp (1916)","Cuando me toque a mi (2006)","Lonliness (2016)","Death on a Rock (2015)","Coeur animal (2009)","\"Mr. Fighting\" (2005)","Youngblood Hawke (1964)","My tattoo (2016)","The Courage of Silence (1917)","Tuch Khari Gharchi Laxmi (2011)","Khuda Ki Shaan (1931)","Between Western and California (2012)","\"Boogie-woogie 47\" (1980)","Ichiban utsukushiku (1944)","The Case of Lena Smith (1929)","Soft Shoes (1925)","A Life to Love (????)","God's Not Dead (2014)","Deool Band (2015)","Dante and Minnie (2012)","Life's Greatest Question (1921)","Candid Sex (2004)","Aarekti Premer Golpo (2010)","Cutback (2010)","Vying for Perfection (2011)","Broken (2011/IV)","Talking to the Trees (2012)","\"Babyfather\" (2001)","Sa.TX (2013)","Taken from Me: The Tiffany Rubin Story (2011)","Hit (2011/II)","Sea of Madness (2006)","\"Alma de hierro\" (2008)","Fight Club (1999)","Het negende uur (2000)","\"Theater Close-Up\" (2014)","Sanam (2000)","Abhishapt (2011)","\"The Secret Garden\" (1960)","Den flyvende cirkus (1912)","...und f\u00fchre uns nicht in Versuchung (1957)","The Girl from Outside (1919)","Pingpong (2006)","Akash Chhoa Bhalobasa (2008)","Podarok Stalinu (2008)","Simon m\u00e1gus (1999)","Rachel (2018)","The Young Doctors (1961)","U zemlji cudesa (2009)","Gaia (2009/I)","Iris och l\u00f6jtnantshj\u00e4rta (1946)","Glowing (2000)","Saddam (2006)","\"Half Moon Investigations\" (2009)","The Brewster Project (2004)","Return to Start (2012)","Kesher Ir (1999)","Joey (1975)","Seasons of Life (2006)","That's Life (2017/I)","Silas Marner: The Weaver of Raveloe (1985)","Virginia (1998)","O agnostos ekeinis tis nyhtas (1972)","\"Undercovers (working title)\" (????)","The Limits (2007)","Gharibe (1972)","\"Mazah fi jad\" (2005)","Mauprat (1926)","Carnival (1921)","Ci mu lei (1953)","Kinema no tenchi (1986)","Casualty: The Kids Aren't Alright (2012)","The Sacrifice of the Rose (????)","Manik (2005)","West Memphis Three (????)","Bedniyat Luka (1979)","Dubbel-8 (2000)","Perfidia (2014/II)","Calm at Sunset (1996)","\"Steppers t ...

# %%
pca = PCA(n_components=3)
X_pca = pca.fit_transform(X)

# %%
fig = px.scatter_3d(x=X_pca[:, 0], y=X_pca[:, 1], z=X_pca[:, 2], color=df['Genre'], opacity=0.8,
                    title="3 Component PCA visualization of Movie Genres", hover_name=df['Title'], template='plotly_dark')
fig.show()
# Out:
# <div>                            <div id="31d8c21f-80d8-4d35-8a4b-40aa9f2c351a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31d8c21f-80d8-4d35-8a4b-40aa9f2c351a")) {                    Plotly.newPlot(                        "31d8c21f-80d8-4d35-8a4b-40aa9f2c351a",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>color=drama<br>x=%{x}<br>y=%{y}<br>z=%{z}<extra></extra>